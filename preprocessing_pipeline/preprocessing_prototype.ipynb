# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import time

from glob import glob
from itertools import cycle

import librosa
import librosa.display
import IPython.display as ipd

# %%
sns.set_theme(style="white", palette = None)
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]
color_cycle = cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])

# %%
class0 = glob("./data/Class0/*/*.mp3")
class1 = glob("./data/Class1/*/*.mp3")

# %%
#normalize recordings to 0-1 scale
y, sr = librosa.load(class0[0])
y_norm = librosa.util.normalize(y)

# %%
#remove silence
y_trim, _ = librosa.effects.trim(y_norm, top_db=20)

# %%
clip_length = 3
clip_length_samples = clip_length*sr
max_len = sr*60
#crop into 1 minute recording
y_cropped = y_trim[:max_len]

#cut into 3s clips
y_clips = librosa.util.frame(y_cropped,
                             frame_length=clip_length_samples,
                             hop_length=clip_length_samples).T
# print(y_clips.shape)
ipd.Audio(y_clips[0], rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#spectograms
mel_spectograms = []
for clip in y_clips:
    S = librosa.feature.melspectrogram(y = clip, sr = sr, n_mels = 128,)
    S_db_mel = librosa.amplitude_to_db(S, ref=np.max)
    mel_spectograms.append(S_db_mel)

    ipd.clear_output(wait=True)
    fig, ax = plt.subplots(figsize = (10,5))
    img = librosa.display.specshow(S_db_mel, x_axis='time', y_axis='log', ax=ax, cmap='inferno')
    fig.colorbar(img, ax=ax, format = f'%0.2f')
    ipd.display(fig)

# %%
#input
X = np.array(mel_spectograms)
np.shape(X) #20 clips, 128 mels, #time steps??? <- co to

#labels
Y = np.ones(X.shape[0]) #create an array of 1's for each clip
# for x, y in zip(Y, X):
#     print(f"{y}: {x}")
# Out:
# [[-74.97419  -64.14318  -38.11953  ... -40.10911  -52.456608 -42.60328 ]
#  [-51.193913 -44.255753 -23.618116 ... -21.529423 -33.736    -28.335697]
#  [-34.204617 -20.906069 -23.390501 ... -23.864532 -34.08776  -30.401731]
#  ...
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]]: 1.0
# [[-32.330513 -27.906166 -30.805573 ... -48.17714  -48.243732 -48.941956]
#  [-21.511368 -17.735508 -12.656879 ... -40.748478 -34.545853 -40.15228 ]
#  [-23.73315  -16.82082  -16.675255 ... -34.64292  -28.336359 -27.13047 ]
#  ...
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]]: 1.0
# [[-54.554184 -50.758526 -41.160606 ... -56.897697 -57.32343  -65.65029 ]
#  [-48.15507  -32.743416 -30.583515 ... -44.507915 -52.398495 -50.180767]
#  [-35.34509  -26.0277   -26.396008 ... -34.667    -31.31541  -34.92298 ]
#  ...
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]]: 1.0
# [[-54.24474  -52.73815  -55.50343  ... -41.74265  -49.58741  -56.051903]
#  [-37.51461  -31.050316 -31.544107 ... -29.845259 -36.87516  -41.624977]
#  [-28.827343 -23.898884 -21.05357  ... -31.60889  -41.19225  -46.74748 ]
#  ...
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]]: 1.0
# [[-54.457684 -38.627457 -31.9435   ... -48.588783 -49.059284 -58.00221 ]
#  [-39.126587 -28.848812 -17.075047 ... -33.525017 -24.427282 -30.555267]
#  [-43.66177  -45.401836 -23.440998 ... -34.28576  -23.139297 -29.704796]
#  ...
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]]: 1.0
# [[-69.60886  -66.48277  -69.32132  ... -51.343323 -49.76334  -45.896885]
#  [-49.08394  -37.437996 -36.1709   ... -28.413351 -30.242626 -31.736715]
#  [-42.246906 -33.213722 -39.986298 ... -30.098818 -30.709333 -32.935455]
#  ...
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]]: 1.0
# [[-47.83142  -56.193787 -61.09099  ... -55.278934 -57.308605 -57.59196 ]
#  [-35.968414 -39.954422 -47.489925 ... -32.275703 -31.250484 -40.646385]
#  [-29.800314 -29.674677 -53.78589  ... -29.832636 -33.39073  -40.153282]
#  ...
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]]: 1.0
# [[-59.977283 -67.19188  -71.28791  ... -57.215183 -66.32068  -63.63351 ]
#  [-42.044014 -36.47427  -41.224262 ... -43.468864 -56.881622 -54.77338 ]
#  [-41.442093 -38.20582  -40.245914 ... -53.35354  -50.191994 -49.280643]
#  ...
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]]: 1.0
# [[